# %% [markdown]
# # TP : Créer un moteur de censure de texte (4/4)
#
# ## Partie 4 :
#
# Idées pour étendre l'exercice :
#
# - censurer plusieurs mots interdits (introduire les listes ? Dire aux étudiants de
#   revenir plus tard ?)
# - Rajouter le pluriel, la conjugaison de certains mots
# - ignorer les accents et les tirets
# -

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[TP : Créer un moteur de censure de texte (3/4)](03-censure-texte3.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Jupyter : se débarrasser de sa souris](../jupyter/jeter-sa-souris.ipynb)|
