# %% [markdown]
# # Prise en main des carnets Jupyter

# %% [markdown]
# Un ***carnet interactif*** est un document interactif permettant de mixer narration,
# interaction, visualisation, calcul ou programmation. Dans ce premier carnet, vous allez
# découvrir les trois opérations essentielles pour utiliser un carnet: lire, exécuter,
# éditer.

# %% [markdown]
# :::{admonition} Définition
# Un carnet interactif est composé d'une séquence de ***cellules***. Chaque cellule peut
# contenir du texte riche, un calcul à effectuer, des visualisations, etc. La ***cellule
# active*** est encadrée, ce qui permet de voir sa portée. C'est l'auteur du document qui a
# préalablement spécifié les propriétés de chaque cellule.
# :::

# %% [markdown]
# **Exercice 1 : à la découverte des cellules**
#
# 1. Cliquez à différents endroits de ce document pour activer tour à tour les cellules qui
#    le compose et voir leur portée.

# %% [markdown]
# **Exercice 2 : utilisation des cellules exécutables**
#
# 1. Cliquez dans la cellule ci-dessous, puis tapez <kbd>Maj</kbd>+<kbd>Entrée</kbd> (la
#    touche <kbd>Maj</kbd> est usuellement accompagnée du symbole ⇧; sur les claviers
#    anglais, elle est dénotée <kbd>Shift</kbd>). Cela **exécutera** le calcul $1+1$ et
#    affichera le résultat :

# %%
1 + 1

# %% [markdown]
# Exécutez de même les cellules ci-dessous, en modifiant les calculs à effectuer selon
# votre goût :

# %%
2 * 3

# %%
2 * (3 + 4)

# %% [markdown]
# :::{attention}
# Dans cette feuille, les exemples de calculs ont volontairement été choisis pour être très
# simples; bien entendu l'intérêt de Jupyter est de donner accès à des calculs bien plus
# riches.
# :::

# %% [markdown]
# **Exercice 3 : modifications des cellules de texte**
#
# 1. Saisissez vos noms et prénoms et couleur préférée dans la cellule ci-dessous.\
#    **Indication :** double cliquez sur la cellule de texte; quand vous avez terminé,
#    appuyez sur les touches <kbd>Maj</kbd>+<kbd>Entrée</kbd>.
# 2. Essayez de modifier la cellule où est écrite ce texte; vous constaterez qu'elle est
#    verrouillée.

# %% [markdown]
# - Nom :
# - Prénom :
# - Couleur préférée :

# %% [markdown]
# <!--
# **Exercice 4 : à la découverte de l'aide en ligne de Jupyter**
#
# 1.  Lancez la visite guidée de l'interface Jupyter.
#     **Indication :** Menu `Aide` -> `Visite de l'interface utilisateur`.
# 2.  Consultez les raccourcis claviers.
#     **Indication :** Menu `Aide` -> `Raccourcis clavier`.
# !-->

# %% [markdown]
# ## Bilan

# %% [markdown]
# Vous savez maintenant lire, exécuter et éditer un carnet Jupyter. Cela sera suffisant
# dans un premier temps pour utiliser des carnets préexistants.

# %% [markdown]
# Vous pouvez maintenant fermer ce carnet -- en fermant son onglet ou mieux avec le
# raccourci clavier <kbd>Ctrl</kbd>+<kbd>Maj</kbd>+<kbd>Q</kbd> -- puis revenir à la
# [page d'accueil](../index.ipynb).

# %% [markdown]
# ||^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# ||[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Prise en main de Laby](../premiers-pas/01-prise-en-main-laby.ipynb)|
