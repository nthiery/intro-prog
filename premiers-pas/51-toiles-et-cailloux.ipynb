# %% [markdown]
# # Toiles et cailloux
#
# Commençons par un petit échauffement avant d'attaquer le défi ci-dessous.
#
# **Indication :** quand il y a une toile, on peut la détruire avec un caillou.

# %% [markdown]
# :::{attention}
# Cet exercice est marqué d'un ♣ et est donc d'un niveau plus avancé ; n'hésitez pas à le
# passer s'il vous paraît difficile afin de ne pas perdre trop de temps, et à revenir
# dessus ultérieurement.
# :::

# %%
from laby.global_fr import *
carte = """
o o o o o o
o → . r w x
o o o o o o
"""
Laby(carte=carte)

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE
ouvre()

# %%
assert est_gagnant()

# %% [markdown]
# Comment résoudre le labyrinthe suivant ?
#
# Attention, le nombre de cailloux / toiles varie !

# %%
from laby.global_fr import *
Laby(lignes=1, colonnes=10, option="rocksAndWebs")

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[Les Toiles](50-les-toiles.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Les boucles `for`](../boucles/02-boucles-for.ipynb)|
