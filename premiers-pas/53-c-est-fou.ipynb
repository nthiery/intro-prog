# %% [markdown]
# # This is Crazy

# %%
from laby.global_fr import *
Laby(niveau = "this-is-crazy")

# %%
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[Fabriquer](54-fabriquer.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Chercher des informations](../jupyter/chercher-des-informations.ipynb)|
