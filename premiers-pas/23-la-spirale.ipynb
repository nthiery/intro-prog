# %% [markdown]
# # La Spirale

# %%
from laby.global_fr import *
Laby(niveau = "4a")

# %% [markdown]
# :::{admonition} Indications
# :class: tip
#
# Procédez comme pour le [labyrinthe en zigzag](22-en-zigzag.ipynb): définissez la fonction
# `avance_tant_que_tu_peux` dans la cellule ci-dessous (par exemple en la recopiant), puis
# écrivez le programme dans la cellule qui suit.
#
# Évitez les répétitions dans le programme en utilisant une boucle while.
# :::

# %%
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE
ouvre()

# %%
assert est_gagnant()

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[En zigzag](22-en-zigzag.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Si, si, si !](30-si-si-si.ipynb)|
