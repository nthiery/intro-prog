# %% [markdown]
# # Le Caillou et la toile
#
# Plus difficile : cette fois, en fonction de l'emplacement des cailloux et toiles, on a
# quatre différentes possibilités. Il va falloir faire des `if`

# %%
from laby.global_fr import *
Laby(niveau = "3b")

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE
ouvre()

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[S'adapter au contexte: les instructions conditionnelles](../conditions/01-conditions.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Jupyter : les deux types de cellules](../jupyter/les-types-de-cellules.ipynb)|
