# %% [markdown]
# # Les Toiles
#
# Par où passer ?

# %% [markdown]
# :::{attention}
# Cet exercice est marqué d'un ♣ et est donc d'un niveau plus avancé ; n'hésitez pas à le
# passer s'il vous paraît difficile afin de ne pas perdre trop de temps, et à revenir
# dessus ultérieurement.
# :::

# %%
from laby.global_fr import *
Laby(niveau = "4b")

# %%
debut()

# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE

# %%
assert est_gagnant()

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[Labyrinthes aléatoires](52-labyrinthes-aleatoires.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Toiles et cailloux](51-toiles-et-cailloux.ipynb)|
