# %% [markdown]
# # Un caillou dans un couloir
#
# Le caillou est maintenant au milieu d'un couloir; comment s'en sortir, sachant que l'on
# ne peut pas ouvrir la porte tout en portant le caillou?

# %%
from laby.global_fr import *
Laby(niveau="1c")

# %%
debut()
# REMPLACEZ TOUTE CETTE LIGNE PAR VOTRE CODE

# %%
assert est_gagnant()

# %% [markdown]
# |< Précédent|^ Remonter ^|Suivant >|
# |:---|:---:|---:|
# |[Un caillou dans la chaussure](11-un-caillou.ipynb)|[Introduction à la programmation, avec Python et Jupyter](../index.ipynb)|[Pas à pas](13-pas-a-pas.ipynb)|
