# %% [markdown]
# # Exercices d'entraînement «Jupylates»
#
# Cette fiche donne accès à une collection d'exercices d'entraînement classés par thèmes.
# Exécutez la cellule suivante, puis choisissez le thème sur lequel vous souhaitez
# travailler.

# %%
from entraîneur import entraîneur
entraîneur
