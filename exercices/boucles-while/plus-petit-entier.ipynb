# %%
import random
from jupylates.jupylates_helpers import SUBSTITUTE

SUBSTITUTE(
    N = random.choice(["n", "m"]),
    K = random.choice(["i", "j", "k", "l"])
)

# %% [markdown]
# :::{admonition} Consigne
#
# Définissez une fonction `plus_petit_entier` qui prend un entier `N` en paramètre et
# renvoie le plus petit entier `K` tel que `1 + 2 + 3 + ... + K > N`.
#
# :::

# %%
def plus_petit_entier(N):
    somme = 0
    K = 0
    while somme <= N:
        K += 1
        somme += K
    return K

# %%
def SOLUTION(N):
    somme = 0
    K = 0
    while somme <= n:
        K += 1
        somme += K
    return K

for N in [100, 221, 9999]:
    assertEquals( plus_petit_entier(N=N),  SOLUTION(N) )
