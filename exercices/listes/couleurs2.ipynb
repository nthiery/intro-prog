# %% [markdown]
# :::{admonition} Objectifs pédagogiques
# déclarer une liste
# :::

# %%
couleurs = ['rose', 'jaune', 'orange', 'vert', 'bleu']
couleurs2 = couleurs.copy()
couleurs2[3] = 'émeraude'

# %% [markdown]
# :::{admonition} Consigne
#
# On suppose que la variable `couleurs` contient une liste de la forme `['rouge', 'jaune', 'orange', 'vert', 'bleu']`.
# Remplacez la couleur `vert` par `émeraude` dans la liste `couleurs`.
#
# :::

# %%
### BEGIN SOLUTION
couleurs[3] = 'émeraude'
### END SOLUTION

# %%
assert couleurs == couleurs2
