# %% [markdown]
# Objectifs pédagogique : Créer une liste d'entiers avec range().

# %% [markdown]
# :::{admonition} Exercice
#
# Créez une liste contenant les entiers de 0 à 10 à l'aide de `list` et `range`.
#
# :::

# %%
### BEGIN SOLUTION
list(range(11))
### END SOLUTION

# %%
assert _ == list(range(11)), f"votre liste contient {_}"
