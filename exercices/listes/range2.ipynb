# %% [markdown]
# Objectifs pédagogique : Créer une liste d'entiers avec range().

# %% [markdown]
# :::{admonition} Exercice
#
# Créez une liste contenant les entiers pairs de 20 à 0 à l'aide de `list` et `range`.
#
# :::

# %%
### BEGIN SOLUTION
list(range(20, -1, -2))
### END SOLUTION

# %%
assert _ == list(range(20, -1, -2)), f"votre liste contient {_}"
