# %% [markdown]
# :::{admonition} Objectifs pédagogiques
# déclarer une liste
# :::

# %% [markdown]
# :::{admonition} Consigne
# Déclarez une liste `couleurs` contenant cinq chaînes de caractères : `rouge`,
#     `jaune`, `orange`, `vert` et `bleu` :
#
# :::

# %%
### BEGIN SOLUTION
couleurs = ['rouge', 'jaune', 'orange', 'vert', 'bleu']
### END SOLUTION

# %%
assert couleurs == ['rouge', 'jaune', 'orange', 'vert', 'bleu']
