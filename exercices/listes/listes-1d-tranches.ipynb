# %%
from random import randint
NROWS = randint(3, 10)
I1 = randint(0, NROWS-2)
I2 = randint(I1+1, NROWS-1)
T = [randint(0,100) for _ in range(NROWS)]

# %% [markdown]
# :::{admonition} Consigne
#
# Observez le code suivant :
# ```
# T = {eval}` T `
# a = T[{eval}` I1 `:{eval}` I2 `]
# ```
#
# Quelle est la valeur de `a` ?
#
# :::

# %%
answer = _
solution = T[I1:I2]
answer

# %%
assert answer == solution
